# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./data/bank-data.csv.gz', compression='gzip', sep=',')
df.head()
# Out:
#    SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 1                 1                              0.766127   45
# 2                 0                              0.957151   40
# 3                 0                              0.658180   38
# 4                 0                              0.233810   30
# 5                 0                              0.907239   49
#
#    NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 1                                     2   0.802982         9120.0
# 2                                     0   0.121876         2600.0
# 3                                     1   0.085113         3042.0
# 4                                     0   0.036050         3300.0
# 5                                     1   0.024926        63588.0
#
#    NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# 1                               13                        0
# 2                                4                        0
# ...

# %% [markdown]
# <br/>**1. Смотрим размер набора данных**

# %%
df.shape
# Out:
# (150000, 11)

# %% [markdown]
# <br/>**2. Выводим названия колонок**

# %%
df.columns
# Out:
# Index(['SeriousDlqin2yrs', 'RevolvingUtilizationOfUnsecuredLines', 'age',
#        'NumberOfTime30-59DaysPastDueNotWorse', 'DebtRatio', 'MonthlyIncome',
#        'NumberOfOpenCreditLinesAndLoans', 'NumberOfTimes90DaysLate',
#        'NumberRealEstateLoansOrLines', 'NumberOfTime60-89DaysPastDueNotWorse',
#        'NumberOfDependents'],
#       dtype='object')

# %% [markdown]
# <br/>**3. Смотрим информацию по каждой колонке**

# %%
df.info(verbose = True, null_counts = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150000 entries, 1 to 150000
# Data columns (total 11 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   SeriousDlqin2yrs                      150000 non-null  int64
#  1   RevolvingUtilizationOfUnsecuredLines  150000 non-null  float64
#  2   age                                   150000 non-null  int64
#  3   NumberOfTime30-59DaysPastDueNotWorse  150000 non-null  int64
#  4   DebtRatio                             150000 non-null  float64
#  5   MonthlyIncome                         120269 non-null  float64
#  6   NumberOfOpenCreditLinesAndLoans       150000 non-null  int64
#  7   NumberOfTimes90DaysLate               150000 non-null  int64
#  8   NumberRealEstateLoansOrLines          150000 non-null  int64
#  9   NumberOfTime60-89DaysPastDueNotWorse  150000 non-null  int64
# ...

# %% [markdown]
# <br/>**4. Выводим характеристики каждого признака**

# %%
df.describe()
# Out:
#        SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines            age  \
# count     150000.000000                         150000.000000  150000.000000
# mean           0.066840                              6.048438      52.295207
# std            0.249746                            249.755371      14.771866
# min            0.000000                              0.000000       0.000000
# 25%            0.000000                              0.029867      41.000000
# 50%            0.000000                              0.154181      52.000000
# 75%            0.000000                              0.559046      63.000000
# max            1.000000                          50708.000000     109.000000
#
#        NumberOfTime30-59DaysPastDueNotWorse      DebtRatio  MonthlyIncome  \
# count                         150000.000000  150000.000000   1.202690e+05
# mean                               0.421033     353.005076   6.670221e+03
# ...

# %% [markdown]
# <br/>**5. Выводим соотношение между 1 и 0 для SeriousDlqin2yrs**

# %%
df['SeriousDlqin2yrs'].value_counts()
# Out:
# 0    139974
# 1     10026
# Name: SeriousDlqin2yrs, dtype: int64

# %% [markdown]
# <br/>**6. Определим средний возраст**

# %%
df['age'].mean()
# Out:
# 52.295206666666665

# %% [markdown]
# <br/>**7. Создадим свобную табличку для SeriousDlqin2yrs по признакам:**
# - NumberOfTime30-59DaysPastDueNotWorse
# - NumberOfTime60-89DaysPastDueNotWorse
# - NumberOfTimes90DaysLate
#
# Соберём по mean**

# %%
pd.pivot_table(df, values = ['NumberOfTime30-59DaysPastDueNotWorse','NumberOfTime60-89DaysPastDueNotWorse','NumberOfTimes90DaysLate'], 
                   index='SeriousDlqin2yrs', 
                   aggfunc = {'NumberOfTime30-59DaysPastDueNotWorse' : np.mean,
                              'NumberOfTime60-89DaysPastDueNotWorse' : np.mean,
                              'NumberOfTimes90DaysLate' : np.mean})
# Out:
#                   NumberOfTime30-59DaysPastDueNotWorse  \
# SeriousDlqin2yrs
# 0                                             0.280109
# 1                                             2.388490
#
#                   NumberOfTime60-89DaysPastDueNotWorse  \
# SeriousDlqin2yrs
# 0                                             0.126666
# 1                                             1.828047
#
#                   NumberOfTimes90DaysLate
# SeriousDlqin2yrs
# 0                                0.135225
# 1                                2.091362

# %% [markdown]
# <br/>**8. Визуализируем распределение переменной age для SeriousDlqin2yrs**

# %%
df.hist(column = 'SeriousDlqin2yrs', bins = 2)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000026F3E76F2C8>]],
#       dtype=object)

# %% [markdown]
# <br/>**9. Посмотрим на частоты признака NumberOfDependents**

# %%
df['NumberOfDependents'].value_counts(normalize = True)
# Out:
# 0.0     0.594909
# 1.0     0.180153
# 2.0     0.133643
# 3.0     0.064918
# 4.0     0.019593
# 5.0     0.005107
# 6.0     0.001082
# 7.0     0.000349
# 8.0     0.000164
# 9.0     0.000034
# 10.0    0.000034
# 13.0    0.000007
# 20.0    0.000007
# Name: NumberOfDependents, dtype: float64

# %% [markdown]
# <br/>**10. Узнаем максимальное значение по каждому признаку**

# %%
df.apply(np.max, axis=0)
# Out:
# SeriousDlqin2yrs                              1.0
# RevolvingUtilizationOfUnsecuredLines      50708.0
# age                                         109.0
# NumberOfTime30-59DaysPastDueNotWorse         98.0
# DebtRatio                                329664.0
# MonthlyIncome                           3008750.0
# NumberOfOpenCreditLinesAndLoans              58.0
# NumberOfTimes90DaysLate                      98.0
# NumberRealEstateLoansOrLines                 54.0
# NumberOfTime60-89DaysPastDueNotWorse         98.0
# NumberOfDependents                           20.0
# dtype: float64

# %% [markdown]
# <br/>**11. Выведем ту часть таблицы, для которой значение признака age > 65**

# %%
df[df['age']>65]
# Out:
#         SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 6                      0                              0.213179   74
# 15                     0                              0.019657   76
# 17                     0                              0.061086   78
# 28                     0                              0.034421   69
# 38                     0                              1.000000   75
# ...                  ...                                   ...  ...
# 149972                 0                              0.058001   83
# 149977                 0                              0.000627   76
# 149984                 0                              0.002485   82
# 149985                 0                              0.037548   84
# 149996                 0                              0.040674   74
#
#         NumberOfTime30-59DaysPastDueNotWorse    DebtRatio  MonthlyIncome  \
# 6                                          0     0.375607         3500.0
# ...

# %% [markdown]
# <br/>**12. Сгруппируем таблицу по SeriousDlqin2yrs и посмотрим статистику для признаков 'RevolvingUtilizationOfUnsecuredLines', 'age', 'DebtRatio'**

# %%
df[['SeriousDlqin2yrs','RevolvingUtilizationOfUnsecuredLines', 'age', 'DebtRatio']].groupby('SeriousDlqin2yrs').describe(percentiles=[])
# Out:
#                  RevolvingUtilizationOfUnsecuredLines                        \
#                                                 count      mean         std
# SeriousDlqin2yrs
# 0                                            139974.0  6.168855  256.126350
# 1                                             10026.0  4.367282  131.835778
#
#                                                age                        \
#                   min       50%      max     count       mean        std
# SeriousDlqin2yrs
# 0                 0.0  0.133288  50708.0  139974.0  52.751375  14.791079
# 1                 0.0  0.838853   8328.0   10026.0  45.926591  12.916289
#
#                                     DebtRatio                                \
#                    min   50%    max     count        mean          std  min
# SeriousDlqin2yrs
# 0                  0.0  52.0  109.0  139974.0  357.151168  2083.282060  0.0
# 1                 21.0  45.0  101.0   10026.0  295.121066  1238.360283  0.0
#
#
# ...

# %% [markdown]
# <br/>**13. Тоже самое, только для mean, std, min, max**

# %%
df[['SeriousDlqin2yrs','RevolvingUtilizationOfUnsecuredLines', 'age', 'DebtRatio']].groupby('SeriousDlqin2yrs' ).agg([np.mean, np.std, np.min, np.max])
# Out:
#                  RevolvingUtilizationOfUnsecuredLines                   \
#                                                  mean         std amin
# SeriousDlqin2yrs
# 0                                            6.168855  256.126350  0.0
# 1                                            4.367282  131.835778  0.0
#
#                                  age                        DebtRatio  \
#                      amax       mean        std amin amax        mean
# SeriousDlqin2yrs
# 0                 50708.0  52.751375  14.791079    0  109  357.151168
# 1                  8328.0  45.926591  12.916289   21  101  295.121066
#
#
#                           std amin      amax
# SeriousDlqin2yrs
# 0                 2083.282060  0.0  329664.0
# 1                 1238.360283  0.0   38793.0

# %% [markdown]
# <br/>**14. Построим crosstab для полей SeriousDlqin2yrs и age**

# %%
pd.crosstab(df['SeriousDlqin2yrs'], df['age'])
# Out:
# age               0    21   22   23   24   25    26    27    28    29   ...  \
# SeriousDlqin2yrs                                                        ...
# 0                   1  170  398  571  718  832  1046  1172  1355  1523  ...
# 1                   0   13   36   70   98  121   147   166   205   179  ...
#
# age               96   97   98   99   101  102  103  105  107  109
# SeriousDlqin2yrs
# 0                  18   17    6    7    2    3    3    1    1    2
# 1                   0    0    0    2    1    0    0    0    0    0
#
# [2 rows x 86 columns]

# %% [markdown]
# <br/>**15. Построим crosstab для полей SeriousDlqin2yrs и age + нормализация**

# %%
pd.crosstab(df['SeriousDlqin2yrs'], df['age'], normalize = True)
# Out:
# age                    0         21        22        23        24        25   \
# SeriousDlqin2yrs
# 0                 0.000007  0.001133  0.002653  0.003807  0.004787  0.005547
# 1                 0.000000  0.000087  0.000240  0.000467  0.000653  0.000807
#
# age                    26        27        28        29   ...      96   \
# SeriousDlqin2yrs                                          ...
# 0                 0.006973  0.007813  0.009033  0.010153  ...  0.00012
# 1                 0.000980  0.001107  0.001367  0.001193  ...  0.00000
#
# age                    97       98        99        101      102      103  \
# SeriousDlqin2yrs
# 0                 0.000113  0.00004  0.000047  0.000013  0.00002  0.00002
# 1                 0.000000  0.00000  0.000013  0.000007  0.00000  0.00000
#
# age                    105       107       109
# SeriousDlqin2yrs
# 0                 0.000007  0.000007  0.000013
# 1                 0.000000  0.000000  0.000000
#
# [2 rows x 86 columns]
